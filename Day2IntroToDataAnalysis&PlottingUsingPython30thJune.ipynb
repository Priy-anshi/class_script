# %% [markdown]
# <a href="https://colab.research.google.com/github/Priy-anshi/class_script/blob/main/Day2IntroToDataAnalysis%26PlottingUsingPython30thJune.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Github Upload

# %%
# import pandas as pd

# # Replace 'raw_github_url' with the raw URL of the CSV file
# raw_github_url = 'https://github.com/swcarpentry/python-novice-gapminder/blob/a6c060a7933df7c04c36fed588a5205fd884bbd8/episodes/data/asia_gdp_per_capita.csv'
# df_github = pd.read_csv(raw_github_url)
# df_github.head()

# %% [markdown]
# # Using Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
url =  '/content/drive/MyDrive/Python Course Operations/gapminder_gdp_asia.csv'

# %%
import pandas as pd

# %%
df_asia = pd.read_csv(url)

# %%
df_asia
# Out:
#                country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0          Afghanistan      779.445314      820.853030      853.100710
# 1              Bahrain     9867.084765    11635.799450    12753.275140
# 2           Bangladesh      684.244172      661.637458      686.341554
# 3             Cambodia      368.469286      434.038336      496.913648
# 4                China      400.448611      575.987001      487.674018
# 5      Hong Kong China     3054.421209     3629.076457     4692.648272
# 6                India      546.565749      590.061996      658.347151
# 7            Indonesia      749.681655      858.900271      849.289770
# 8                 Iran     3035.326002     3290.257643     4187.329802
# 9                 Iraq     4129.766056     6229.333562     8341.737815
# 10              Israel     4086.522128     5385.278451     7105.630706
# 11               Japan     3216.956347     4317.694365     6576.649461
# ...

# %%
df_movies= pd.read_csv('/content/drive/MyDrive/Python Course Operations/movie.csv')

# %%
df_asia = pd.read_csv(url, index_col='country')
print(df_asia)
# Out:
#                     gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Afghanistan             779.445314      820.853030      853.100710
# Bahrain                9867.084765    11635.799450    12753.275140
# Bangladesh              684.244172      661.637458      686.341554
# Cambodia                368.469286      434.038336      496.913648
# China                   400.448611      575.987001      487.674018
# Hong Kong China        3054.421209     3629.076457     4692.648272
# India                   546.565749      590.061996      658.347151
# Indonesia               749.681655      858.900271      849.289770
# Iran                   3035.326002     3290.257643     4187.329802
# Iraq                   4129.766056     6229.333562     8341.737815
# Israel                 4086.522128     5385.278451     7105.630706
# Japan                  3216.956347     4317.694365     6576.649461
# Jordan                 1546.907807     1886.080591     2348.009158
# ...

# %%
df_asia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, Afghanistan to Yemen Rep.
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gdpPercap_1952  33 non-null     float64
#  1   gdpPercap_1957  33 non-null     float64
#  2   gdpPercap_1962  33 non-null     float64
#  3   gdpPercap_1967  33 non-null     float64
#  4   gdpPercap_1972  33 non-null     float64
#  5   gdpPercap_1977  33 non-null     float64
#  6   gdpPercap_1982  33 non-null     float64
#  7   gdpPercap_1987  33 non-null     float64
#  8   gdpPercap_1992  33 non-null     float64
#  9   gdpPercap_1997  33 non-null     float64
#  10  gdpPercap_2002  33 non-null     float64
#  11  gdpPercap_2007  33 non-null     float64
# dtypes: float64(12)
# memory usage: 3.4+ KB

# %%
print(df_asia.columns)
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
df_asia = df_asia.T

# %%
df_asia
# Out:
# country         Afghanistan       Bahrain   Bangladesh     Cambodia  \
# gdpPercap_1952   779.445314   9867.084765   684.244172   368.469286
# gdpPercap_1957   820.853030  11635.799450   661.637458   434.038336
# gdpPercap_1962   853.100710  12753.275140   686.341554   496.913648
# gdpPercap_1967   836.197138  14804.672700   721.186086   523.432314
# gdpPercap_1972   739.981106  18268.658390   630.233627   421.624026
# gdpPercap_1977   786.113360  19340.101960   659.877232   524.972183
# gdpPercap_1982   978.011439  19211.147310   676.981866   624.475478
# gdpPercap_1987   852.395945  18524.024060   751.979403   683.895573
# gdpPercap_1992   649.341395  19035.579170   837.810164   682.303175
# gdpPercap_1997   635.341351  20292.016790   972.770035   734.285170
# gdpPercap_2002   726.734055  23403.559270  1136.390430   896.226015
# gdpPercap_2007   974.580338  29796.048340  1391.253792  1713.778686
#
# country               China  Hong Kong China        India    Indonesia  \
# ...

# %%
df_asia.describe()
# Out:
# country  Afghanistan       Bahrain   Bangladesh     Cambodia        China  \
# count      12.000000     12.000000    12.000000    12.000000    12.000000
# mean      802.674598  18077.663945   817.558818   675.367824  1488.307694
# std       108.202929   5415.413364   235.079648   360.254866  1370.628333
# min       635.341351   9867.084765   630.233627   368.469286   400.448611
# 25%       736.669343  14291.823310   673.145764   481.194820   603.526020
# 50%       803.483195  18779.801615   703.763820   574.723831   851.829425
# 75%       852.572136  19578.080667   871.550132   696.492972  1814.146653
# max       978.011439  29796.048340  1391.253792  1713.778686  4959.114854
#
# country  Hong Kong China        India    Indonesia          Iran  \
# count          12.000000    12.000000    12.000000     12.000000
# mean        16228.700865  1057.296307  1741.365360   7376.582905
# std         12207.329731   570.248221   996.510872   2954.183911
# ...

# %%
df_asia.describe(include='all')
# Out:
# country  Afghanistan       Bahrain   Bangladesh     Cambodia        China  \
# count      12.000000     12.000000    12.000000    12.000000    12.000000
# mean      802.674598  18077.663945   817.558818   675.367824  1488.307694
# std       108.202929   5415.413364   235.079648   360.254866  1370.628333
# min       635.341351   9867.084765   630.233627   368.469286   400.448611
# 25%       736.669343  14291.823310   673.145764   481.194820   603.526020
# 50%       803.483195  18779.801615   703.763820   574.723831   851.829425
# 75%       852.572136  19578.080667   871.550132   696.492972  1814.146653
# max       978.011439  29796.048340  1391.253792  1713.778686  4959.114854
#
# country  Hong Kong China        India    Indonesia          Iran  \
# count          12.000000    12.000000    12.000000     12.000000
# mean        16228.700865  1057.296307  1741.365360   7376.582905
# std         12207.329731   570.248221   996.510872   2954.183911
# ...

# %%
help(df_asia.head)
# Out:
# Help on method head in module pandas.core.generic:
#
# head(n: 'int' = 5) -> 'NDFrameT' method of pandas.core.frame.DataFrame instance
#     Return the first `n` rows.
#
#     This function returns the first `n` rows for the object based
#     on position. It is useful for quickly testing if your object
#     has the right type of data in it.
#
#     For negative values of `n`, this function returns all rows except
#     the last `|n|` rows, equivalent to ``df[:n]``.
#
#     If n is larger than the number of rows, this function returns all rows.
#
#     Parameters
#     ----------
#     n : int, default 5
#         Number of rows to select.
#
#     Returns
#     -------
#     same type as caller
#         The first `n` rows of the caller object.
#
#     See Also
#     --------
#     DataFrame.tail: Returns the last `n` rows.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({'animal': ['alligator', 'bee', 'falcon', 'lion',
# ...

# %%
df_asia.head()
# Out:
# country         Afghanistan       Bahrain  Bangladesh    Cambodia       China  \
# gdpPercap_1952   779.445314   9867.084765  684.244172  368.469286  400.448611
# gdpPercap_1957   820.853030  11635.799450  661.637458  434.038336  575.987001
# gdpPercap_1962   853.100710  12753.275140  686.341554  496.913648  487.674018
# gdpPercap_1967   836.197138  14804.672700  721.186086  523.432314  612.705693
# gdpPercap_1972   739.981106  18268.658390  630.233627  421.624026  676.900092
#
# country         Hong Kong China       India    Indonesia         Iran  \
# gdpPercap_1952      3054.421209  546.565749   749.681655  3035.326002
# gdpPercap_1957      3629.076457  590.061996   858.900271  3290.257643
# gdpPercap_1962      4692.648272  658.347151   849.289770  4187.329802
# gdpPercap_1967      6197.962814  700.770611   762.431772  5906.731805
# gdpPercap_1972      8315.928145  724.032527  1111.107907  9613.818607
#
# country                Iraq  ...  Philippines  Saudi Arabia    Singapore  \
# ...

# %%
df_asia.tail()
# Out:
# country         Afghanistan      Bahrain   Bangladesh     Cambodia  \
# gdpPercap_1987   852.395945  18524.02406   751.979403   683.895573
# gdpPercap_1992   649.341395  19035.57917   837.810164   682.303175
# gdpPercap_1997   635.341351  20292.01679   972.770035   734.285170
# gdpPercap_2002   726.734055  23403.55927  1136.390430   896.226015
# gdpPercap_2007   974.580338  29796.04834  1391.253792  1713.778686
#
# country               China  Hong Kong China        India    Indonesia  \
# gdpPercap_1987  1378.904018      20038.47269   976.512676  1748.356961
# gdpPercap_1992  1655.784158      24757.60301  1164.406809  2383.140898
# gdpPercap_1997  2289.234136      28377.63219  1458.817442  3119.335603
# gdpPercap_2002  3119.280896      30209.01516  1746.769454  2873.912870
# gdpPercap_2007  4959.114854      39724.97867  2452.210407  3540.651564
#
# country                 Iran          Iraq  ...  Philippines  Saudi Arabia  \
# ...

# %%
df_asia.iloc[0,0]
# Out:
# 779.4453145

# %%
df_asia.loc['gdpPercap_1952',:]
# Out:
# country
# Afghanistan              779.445314
# Bahrain                 9867.084765
# Bangladesh               684.244172
# Cambodia                 368.469286
# China                    400.448611
# Hong Kong China         3054.421209
# India                    546.565749
# Indonesia                749.681655
# Iran                    3035.326002
# Iraq                    4129.766056
# Israel                  4086.522128
# Japan                   3216.956347
# Jordan                  1546.907807
# Korea Dem. Rep.         1088.277758
# Korea Rep.              1030.592226
# Kuwait                108382.352900
# Lebanon                 4834.804067
# Malaysia                1831.132894
# Mongolia                 786.566857
# Myanmar                  331.000000
# Nepal                    545.865723
# Oman                    1828.230307
# Pakistan                 684.597144
# Philippines             1272.880995
# Saudi Arabia            6459.554823
# Singapore               2315.138227
# ...

# %%
df_asia.loc[:,'Taiwan']
# Out:
# gdpPercap_1952     1206.947913
# gdpPercap_1957     1507.861290
# gdpPercap_1962     1822.879028
# gdpPercap_1967     2643.858681
# gdpPercap_1972     4062.523897
# gdpPercap_1977     5596.519826
# gdpPercap_1982     7426.354774
# gdpPercap_1987    11054.561750
# gdpPercap_1992    15215.657900
# gdpPercap_1997    20206.820980
# gdpPercap_2002    23235.423290
# gdpPercap_2007    28718.276840
# Name: Taiwan, dtype: float64

# %%
df_asia.loc['gdpPercap_1952':'gdpPercap_2007','Pakistan']
# Out:
# gdpPercap_1952     684.597144
# gdpPercap_1957     747.083529
# gdpPercap_1962     803.342742
# gdpPercap_1967     942.408259
# gdpPercap_1972    1049.938981
# gdpPercap_1977    1175.921193
# gdpPercap_1982    1443.429832
# gdpPercap_1987    1704.686583
# gdpPercap_1992    1971.829464
# gdpPercap_1997    2049.350521
# gdpPercap_2002    2092.712441
# gdpPercap_2007    2605.947580
# Name: Pakistan, dtype: float64

# %%
df_asia.loc['gdpPercap_1957'].max()
# Out:
# 113523.1329

# %%
df_asia.loc['gdpPercap_1957',:].max()
# Out:
# 113523.1329
